# %%
# !py -m pip install serpapi pandas python-dotenv
# Out:
# Collecting serpapi
#   Downloading serpapi-0.1.5-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: python-dotenv in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (1.0.1)
# Requirement already satisfied: requests in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (from serpapi) (2.31.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (from requests->serpapi) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (from requests->serpapi) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (from requests->serpapi) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nischroe\appdata\local\programs\python\python312\lib\site-packages (from requests->serpapi) (2024.2.2)
# Downloading serpapi-0.1.5-py2.py3-none-any.whl (10 kB)
# Installing collected packages: serpapi
# Successfully installed serpapi-0.1.5

# %%
# Import required libraries
import serpapi
from dotenv import load_dotenv
import pandas as pd
import os

# Load environment variables from the .env file
load_dotenv()
# Out:
# True

# %%
all_extracted_data = []

# %%
# Your API Key can be found at https://serpapi.com/manage-api-key
client = serpapi.Client(api_key=os.getenv("SERPAPI_KEY"))   

 # Master data list used to create .csv file later on
page_number = 1         # Assign initial page_number value as 1

for _ in range(30):
    results = client.search({
            "engine": "google_patents", # Define engine
            "q": "(Automotive)",            # Your search query
            "page": page_number         # Page number, defined before
    })

    organic_results = results["organic_results"] 

    # Extract data from each result
    extracted_data = []
    for result in organic_results:
        data = {
            "position":result.get("position"),
            "rank": result.get("rank"),
            "patent_id": result.get("patent_id"),
            "serpapi_link": result.get("serpapi_link"),
            "title": result.get("title"),
            "priority_date": result.get("priority_date"),
            "filing_date": result.get("filing_date"),
            "grant_date": result.get("grant_date"),
            "publication_date": result.get("publication_date"),
            "inventor": result.get("inventor"),
            "assignee": result.get("assignee"),
            "publication_number": result.get("publication_number"),
            "language": result.get("language"),
            "thumbnail":result.get("thumbnail"),
            "pdf": result.get("pdf"),
            "page": page_number
        }

        extracted_data.append(data)

    # Add the extracted data to the master data list
    all_extracted_data.extend(extracted_data)   
    
    # Increment page number value by 1 or end the loop
    if "next" in results["serpapi_pagination"]:
        page_number +=1 
    else:
        break

# %%
all_extracted_data
# Out:
# [{'position': 1,
#   'rank': 0,
#   'patent_id': 'patent/US10427604B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10427604B2%2Fen',
#   'title': 'Vision system for a vehicle',
#   'priority_date': '2000-03-02',
#   'filing_date': '2018-08-27',
#   'grant_date': '2019-10-01',
#   'publication_date': '2019-10-01',
#   'inventor': 'Kenneth Schofield',
#   'assignee': 'Magna Electronics Inc.',
#   'publication_number': 'US10427604B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/24/7d/d7/f5c6b523a64b07/US10427604-20191001-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/57/a2/97/f38685612beffe/US10427604.pdf'},
#  {'position': 2,
#   'rank': 1,
#   'patent_id': 'patent/US20210234767A1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS20210234767A1%2Fen',
#   'title': 'Vehicle middleware',
#   'priority_date': '2011-11-16',
#   'filing_date': '2021-04-16',
#   'grant_date': None,
#   'publication_date': '2021-07-29',
#   'inventor': 'Christopher P. Ricci',
#   'assignee': 'Autoconnect Holdings Llc',
#   'publication_number': 'US20210234767A1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/aa/b4/95/7aefdc31ecb92c/US20210234767A1-20210729-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/42/1e/f1/02cf5e39df65cb/US20210234767A1.pdf'},
#  {'position': 3,
#   'rank': 2,
#   'patent_id': 'patent/US10979875B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10979875B2%2Fen',
#   'title': 'System and method for wireless interface selection and for communication and …',
#   'priority_date': '2011-01-14',
#   'filing_date': '2018-09-11',
#   'grant_date': '2021-04-13',
#   'publication_date': '2021-04-13',
#   'inventor': 'Lillian Lei Dai',
#   'assignee': 'Cisco Technology, Inc.',
#   'publication_number': 'US10979875B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/46/2c/7d/8b20081b45f79b/US10979875-20210413-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/31/9c/dd/a6dead13207d15/US10979875.pdf'},
#  {'position': 4,
#   'rank': 3,
#   'patent_id': 'patent/US10320836B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10320836B2%2Fen',
#   'title': 'Automotive ECU controller and data network having security features for …',
#   'priority_date': '2017-01-03',
#   'filing_date': '2018-07-16',
#   'grant_date': '2019-06-11',
#   'publication_date': '2019-06-11',
#   'inventor': 'Tal Efraim Ben David',
#   'assignee': 'Karamba Security Ltd.',
#   'publication_number': 'US10320836B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/50/98/c1/98ebb5b70b2dea/US10320836-20190611-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/40/6a/97/16488405fd862b/US10320836.pdf'},
#  {'position': 5,
#   'rank': 4,
#   'patent_id': 'patent/US11790420B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11790420B2%2Fen',
#   'title': 'Visual discovery tool for automotive manufacturers with network encryption, …',
#   'priority_date': '2016-10-18',
#   'filing_date': '2021-01-04',
#   'grant_date': '2023-10-17',
#   'publication_date': '2023-10-17',
#   'inventor': 'Jeffrey Stuart Cotton',
#   'assignee': 'Autoalert, Llc',
#   'publication_number': 'US11790420B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/38/c4/91/67d4475baf600a/US11790420-20231017-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/f7/48/8f/9cc74b3f4af166/US11790420.pdf'},
#  {'position': 6,
#   'rank': 5,
#   'patent_id': 'patent/US10613579B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10613579B2%2Fen',
#   'title': 'Automotive display device',
#   'priority_date': '2015-03-02',
#   'filing_date': '2019-01-30',
#   'grant_date': '2020-04-07',
#   'publication_date': '2020-04-07',
#   'inventor': 'Seong Min Wang',
#   'assignee': 'Samsung Display Co., Ltd.',
#   'publication_number': 'US10613579B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/68/c6/c5/d8a147376990d2/US10613579-20200407-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/2d/51/4f/34c7a66438e12c/US10613579.pdf'},
#  {'position': 7,
#   'rank': 6,
#   'patent_id': 'patent/US11250648B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11250648B2%2Fen',
#   'title': 'Predictive maintenance of automotive transmission',
#   'priority_date': '2019-12-18',
#   'filing_date': '2019-12-18',
#   'grant_date': '2022-02-15',
#   'publication_date': '2022-02-15',
#   'inventor': 'Poorna Kale',
#   'assignee': 'Micron Technology, Inc.',
#   'publication_number': 'US11250648B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/d3/00/05/c61288ba7f7623/US11250648-20220215-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/36/cb/10/9d675c05be7a0e/US11250648.pdf'},
#  {'position': 8,
#   'rank': 7,
#   'patent_id': 'patent/US11627433B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11627433B2%2Fen',
#   'title': 'Enhanced automotive passive entry',
#   'priority_date': '2017-02-10',
#   'filing_date': '2021-12-21',
#   'grant_date': '2023-04-11',
#   'publication_date': '2023-04-11',
#   'inventor': 'Brent M. Ledvina',
#   'assignee': 'Apple Inc.',
#   'publication_number': 'US11627433B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/7f/f3/02/777d0176382075/US11627433-20230411-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/95/ce/1b/3b9e89d8fbcb99/US11627433.pdf'},
#  {'position': 9,
#   'rank': 8,
#   'patent_id': 'patent/US11380107B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11380107B2%2Fen',
#   'title': 'Power and data center (PDC) for automotive applications',
#   'priority_date': '2018-06-29',
#   'filing_date': '2019-06-28',
#   'grant_date': '2022-07-05',
#   'publication_date': '2022-07-05',
#   'inventor': 'Lee Bauer',
#   'assignee': 'Aptiv Technologies Limited',
#   'publication_number': 'US11380107B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/83/2f/9f/878338d2d87d9e/US11380107-20220705-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/ca/5e/6b/760214daa52ee3/US11380107.pdf'},
#  {'position': 10,
#   'rank': 9,
#   'patent_id': 'patent/CN111630404B/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FCN111630404B%2Fen',
#   'title': 'Detection, mitigation and avoidance of mutual interference between automotive …',
#   'priority_date': '2017-11-29',
#   'filing_date': '2018-11-25',
#   'grant_date': '2023-10-20',
#   'publication_date': '2023-10-20',
#   'inventor': '约拉姆·斯特廷尔',
#   'assignee': '阿尔贝机器人有限公司',
#   'publication_number': 'CN111630404B',
#   'language': 'en',
#   'thumbnail': None,
#   'pdf': 'https://patentimages.storage.googleapis.com/a0/52/9d/1ce4259ad42400/CN111630404B.pdf'},
#  {'position': 1,
#   'rank': 0,
#   'patent_id': 'patent/US10427604B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10427604B2%2Fen',
#   'title': 'Vision system for a vehicle',
#   'priority_date': '2000-03-02',
#   'filing_date': '2018-08-27',
#   'grant_date': '2019-10-01',
#   'publication_date': '2019-10-01',
#   'inventor': 'Kenneth Schofield',
#   'assignee': 'Magna Electronics Inc.',
#   'publication_number': 'US10427604B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/24/7d/d7/f5c6b523a64b07/US10427604-20191001-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/57/a2/97/f38685612beffe/US10427604.pdf',
#   'page': 1},
#  {'position': 2,
#   'rank': 1,
#   'patent_id': 'patent/US20210234767A1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS20210234767A1%2Fen',
#   'title': 'Vehicle middleware',
#   'priority_date': '2011-11-16',
#   'filing_date': '2021-04-16',
#   'grant_date': None,
#   'publication_date': '2021-07-29',
#   'inventor': 'Christopher P. Ricci',
#   'assignee': 'Autoconnect Holdings Llc',
#   'publication_number': 'US20210234767A1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/aa/b4/95/7aefdc31ecb92c/US20210234767A1-20210729-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/42/1e/f1/02cf5e39df65cb/US20210234767A1.pdf',
#   'page': 1},
#  {'position': 3,
#   'rank': 2,
#   'patent_id': 'patent/US10979875B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10979875B2%2Fen',
#   'title': 'System and method for wireless interface selection and for communication and …',
#   'priority_date': '2011-01-14',
#   'filing_date': '2018-09-11',
#   'grant_date': '2021-04-13',
#   'publication_date': '2021-04-13',
#   'inventor': 'Lillian Lei Dai',
#   'assignee': 'Cisco Technology, Inc.',
#   'publication_number': 'US10979875B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/46/2c/7d/8b20081b45f79b/US10979875-20210413-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/31/9c/dd/a6dead13207d15/US10979875.pdf',
#   'page': 1},
#  {'position': 4,
#   'rank': 3,
#   'patent_id': 'patent/US10320836B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10320836B2%2Fen',
#   'title': 'Automotive ECU controller and data network having security features for …',
#   'priority_date': '2017-01-03',
#   'filing_date': '2018-07-16',
#   'grant_date': '2019-06-11',
#   'publication_date': '2019-06-11',
#   'inventor': 'Tal Efraim Ben David',
#   'assignee': 'Karamba Security Ltd.',
#   'publication_number': 'US10320836B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/50/98/c1/98ebb5b70b2dea/US10320836-20190611-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/40/6a/97/16488405fd862b/US10320836.pdf',
#   'page': 1},
#  {'position': 5,
#   'rank': 4,
#   'patent_id': 'patent/US11790420B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11790420B2%2Fen',
#   'title': 'Visual discovery tool for automotive manufacturers with network encryption, …',
#   'priority_date': '2016-10-18',
#   'filing_date': '2021-01-04',
#   'grant_date': '2023-10-17',
#   'publication_date': '2023-10-17',
#   'inventor': 'Jeffrey Stuart Cotton',
#   'assignee': 'Autoalert, Llc',
#   'publication_number': 'US11790420B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/38/c4/91/67d4475baf600a/US11790420-20231017-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/f7/48/8f/9cc74b3f4af166/US11790420.pdf',
#   'page': 1},
#  {'position': 6,
#   'rank': 5,
#   'patent_id': 'patent/US10613579B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10613579B2%2Fen',
#   'title': 'Automotive display device',
#   'priority_date': '2015-03-02',
#   'filing_date': '2019-01-30',
#   'grant_date': '2020-04-07',
#   'publication_date': '2020-04-07',
#   'inventor': 'Seong Min Wang',
#   'assignee': 'Samsung Display Co., Ltd.',
#   'publication_number': 'US10613579B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/68/c6/c5/d8a147376990d2/US10613579-20200407-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/2d/51/4f/34c7a66438e12c/US10613579.pdf',
#   'page': 1},
#  {'position': 7,
#   'rank': 6,
#   'patent_id': 'patent/US11250648B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11250648B2%2Fen',
#   'title': 'Predictive maintenance of automotive transmission',
#   'priority_date': '2019-12-18',
#   'filing_date': '2019-12-18',
#   'grant_date': '2022-02-15',
#   'publication_date': '2022-02-15',
#   'inventor': 'Poorna Kale',
#   'assignee': 'Micron Technology, Inc.',
#   'publication_number': 'US11250648B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/d3/00/05/c61288ba7f7623/US11250648-20220215-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/36/cb/10/9d675c05be7a0e/US11250648.pdf',
#   'page': 1},
#  {'position': 8,
#   'rank': 7,
#   'patent_id': 'patent/US11627433B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11627433B2%2Fen',
#   'title': 'Enhanced automotive passive entry',
#   'priority_date': '2017-02-10',
#   'filing_date': '2021-12-21',
#   'grant_date': '2023-04-11',
#   'publication_date': '2023-04-11',
#   'inventor': 'Brent M. Ledvina',
#   'assignee': 'Apple Inc.',
#   'publication_number': 'US11627433B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/7f/f3/02/777d0176382075/US11627433-20230411-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/95/ce/1b/3b9e89d8fbcb99/US11627433.pdf',
#   'page': 1},
#  {'position': 9,
#   'rank': 8,
#   'patent_id': 'patent/US11380107B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11380107B2%2Fen',
#   'title': 'Power and data center (PDC) for automotive applications',
#   'priority_date': '2018-06-29',
#   'filing_date': '2019-06-28',
#   'grant_date': '2022-07-05',
#   'publication_date': '2022-07-05',
#   'inventor': 'Lee Bauer',
#   'assignee': 'Aptiv Technologies Limited',
#   'publication_number': 'US11380107B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/83/2f/9f/878338d2d87d9e/US11380107-20220705-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/ca/5e/6b/760214daa52ee3/US11380107.pdf',
#   'page': 1},
#  {'position': 10,
#   'rank': 9,
#   'patent_id': 'patent/CN111630404B/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FCN111630404B%2Fen',
#   'title': 'Detection, mitigation and avoidance of mutual interference between automotive …',
#   'priority_date': '2017-11-29',
#   'filing_date': '2018-11-25',
#   'grant_date': '2023-10-20',
#   'publication_date': '2023-10-20',
#   'inventor': '约拉姆·斯特廷尔',
#   'assignee': '阿尔贝机器人有限公司',
#   'publication_number': 'CN111630404B',
#   'language': 'en',
#   'thumbnail': None,
#   'pdf': 'https://patentimages.storage.googleapis.com/a0/52/9d/1ce4259ad42400/CN111630404B.pdf',
#   'page': 1},
#  {'position': 1,
#   'rank': 0,
#   'patent_id': 'patent/US11411917B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11411917B2%2Fen',
#   'title': 'Method for detecting, blocking and reporting cyber-attacks against automotive …',
#   'priority_date': '2015-08-03',
#   'filing_date': '2020-05-22',
#   'grant_date': '2022-08-09',
#   'publication_date': '2022-08-09',
#   'inventor': 'Alan Grau',
#   'assignee': 'Sectigo, Inc.',
#   'publication_number': 'US11411917B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/67/9a/6f/4e2464f44bd6c2/US11411917-20220809-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/35/f4/ac/3b5d477ca74feb/US11411917.pdf',
#   'page': 2},
#  {'position': 2,
#   'rank': 1,
#   'patent_id': 'patent/US10846690B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10846690B2%2Fen',
#   'title': 'Automotive optical communication system',
#   'priority_date': '2014-12-30',
#   'filing_date': '2019-02-12',
#   'grant_date': '2020-11-24',
#   'publication_date': '2020-11-24',
#   'inventor': 'Jeremy L. Cattone',
#   'assignee': 'Paypal, Inc.',
#   'publication_number': 'US10846690B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/f4/19/fb/6154870aa75b10/US10846690-20201124-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/2d/06/fb/4bdfbbc674e187/US10846690.pdf',
#   'page': 2},
#  {'position': 3,
#   'rank': 2,
#   'patent_id': 'patent/US11513187B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11513187B2%2Fen',
#   'title': 'FMCW automotive radar incorporating modified slow time processing of fine range …',
#   'priority_date': '2018-05-07',
#   'filing_date': '2019-05-06',
#   'grant_date': '2022-11-29',
#   'publication_date': '2022-11-29',
#   'inventor': 'Yoram Stettiner',
#   'assignee': 'Arbe Robotics Ltd.',
#   'publication_number': 'US11513187B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/94/12/ea/9ac5054eb9558a/US11513187-20221129-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/05/22/4b/1821e57167d520/US11513187B2.pdf',
#   'page': 2},
#  {'position': 4,
#   'rank': 3,
#   'patent_id': 'patent/US11462061B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11462061B2%2Fen',
#   'title': 'Systems and methods for use of diagnostic scan tool in automotive collision …',
#   'priority_date': '2016-04-19',
#   'filing_date': '2019-11-07',
#   'grant_date': '2022-10-04',
#   'publication_date': '2022-10-04',
#   'inventor': 'John Joseph Rozint',
#   'assignee': 'Mitchell International, Inc.',
#   'publication_number': 'US11462061B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/92/57/6f/b35db7c6c89eca/US11462061-20221004-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/4f/65/53/6d4e1f919ff530/US11462061.pdf',
#   'page': 2},
#  {'position': 5,
#   'rank': 4,
#   'patent_id': 'patent/US11038363B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11038363B2%2Fen',
#   'title': 'Battery system to be implemented in an automotive vehicle, wake-up control unit …',
#   'priority_date': '2014-09-30',
#   'filing_date': '2018-07-20',
#   'grant_date': '2021-06-15',
#   'publication_date': '2021-06-15',
#   'inventor': 'Ronald J. Dulle',
#   'assignee': 'Cps Technology Holdings Llc',
#   'publication_number': 'US11038363B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/3d/14/81/ab0cc8849e098f/US11038363-20210615-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/92/c1/b6/4f3f2d88ae7026/US11038363.pdf',
#   'page': 2},
#  {'position': 6,
#   'rank': 5,
#   'patent_id': 'patent/EP3835810B1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FEP3835810B1%2Fen',
#   'title': 'Method and system for frequency offset modulation range division mimo automotive …',
#   'priority_date': '2019-12-09',
#   'filing_date': '2020-11-16',
#   'grant_date': '2024-02-21',
#   'publication_date': '2024-02-21',
#   'inventor': 'Ryan Haoyun Wu',
#   'assignee': 'NXP USA, Inc.',
#   'publication_number': 'EP3835810B1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/6b/c8/50/2981f468fd4a91/imgf0001.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/37/5f/99/70f3993e1566d5/EP3835810B1.pdf',
#   'page': 2},
#  {'position': 7,
#   'rank': 6,
#   'patent_id': 'patent/US20200362610A1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS20200362610A1%2Fen',
#   'title': 'Multiple piece construction automotive door hinge',
#   'priority_date': '2006-07-10',
#   'filing_date': '2020-06-03',
#   'grant_date': None,
#   'publication_date': '2020-11-19',
#   'inventor': 'Robert John Murray',
#   'assignee': 'Multimatic Inc.',
#   'publication_number': 'US20200362610A1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/49/6c/de/4154612a827e27/US20200362610A1-20201119-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/6c/4b/35/d1f5d0287fb82b/US20200362610A1.pdf',
#   'page': 2},
#  {'position': 8,
#   'rank': 7,
#   'patent_id': 'patent/DE102018104723B4/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FDE102018104723B4%2Fen',
#   'title': 'AN AUTOMOTIVE STRUCTURE COMPONENT AND METHOD OF MANUFACTURE',
#   'priority_date': '2017-03-03',
#   'filing_date': '2018-03-01',
#   'grant_date': '2022-05-19',
#   'publication_date': '2022-05-19',
#   'inventor': 'Justin C. Martin',
#   'assignee': 'GM Global Technology Operations LLC',
#   'publication_number': 'DE102018104723B4',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/3d/32/8a/f872d4e64d36d2/DE102018104723B4_0001.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/62/c2/05/c197f87016d58a/DE102018104723B4.pdf',
#   'page': 2},
#  {'position': 9,
#   'rank': 8,
#   'patent_id': 'patent/US11231499B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11231499B2%2Fen',
#   'title': 'Distance detecting systems for use in automotive applications including gallium …',
#   'priority_date': '2017-12-13',
#   'filing_date': '2020-02-06',
#   'grant_date': '2022-01-25',
#   'publication_date': '2022-01-25',
#   'inventor': 'James W. RARING',
#   'assignee': 'Kyocera Sld Laser, Inc.',
#   'publication_number': 'US11231499B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/3d/7e/33/058508882f37a7/US11231499-20220125-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/8d/6f/77/051617bc7d91ff/US11231499.pdf',
#   'page': 2},
#  {'position': 10,
#   'rank': 9,
#   'patent_id': 'patent/US11627444B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11627444B2%2Fen',
#   'title': 'Vehicle-to-everything session and service continuity in automotive edge …',
#   'priority_date': '2018-06-06',
#   'filing_date': '2019-06-05',
#   'grant_date': '2023-04-11',
#   'publication_date': '2023-04-11',
#   'inventor': 'Leifeng Ruan',
#   'assignee': 'Intel Corporation',
#   'publication_number': 'US11627444B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/cb/03/28/1b15c1a93040e8/US11627444-20230411-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/8a/f3/0b/c6424bde64f397/US11627444.pdf',
#   'page': 2},
#  {'position': 1,
#   'rank': 0,
#   'patent_id': 'patent/US10682969B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10682969B2%2Fen',
#   'title': 'Power management systems for automotive video event recorders',
#   'priority_date': '2006-11-07',
#   'filing_date': '2018-07-12',
#   'grant_date': '2020-06-16',
#   'publication_date': '2020-06-16',
#   'inventor': 'James Plante',
#   'assignee': 'Smartdrive Systems, Inc.',
#   'publication_number': 'US10682969B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/44/20/2f/3e52f401684036/US10682969-20200616-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/a0/17/02/0fac057c4819ac/US10682969.pdf',
#   'page': 3},
#  {'position': 2,
#   'rank': 1,
#   'patent_id': 'patent/US10416490B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10416490B2%2Fen',
#   'title': 'Curved display and automotive device',
#   'priority_date': '2016-03-30',
#   'filing_date': '2018-07-31',
#   'grant_date': '2019-09-17',
#   'publication_date': '2019-09-17',
#   'inventor': 'Masafumi Hirata',
#   'assignee': 'Panasonic Liquid Crystal Display Co., Ltd.',
#   'publication_number': 'US10416490B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/27/bf/12/8af07c6925748a/US10416490-20190917-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/37/bd/c4/07a6938654ea44/US10416490.pdf',
#   'page': 3},
#  {'position': 3,
#   'rank': 2,
#   'patent_id': 'patent/JP7224473B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FJP7224473B2%2Fen',
#   'title': 'Automotive Windshield Adhesive Dispensing System',
#   'priority_date': '2019-03-11',
#   'filing_date': '2020-02-20',
#   'grant_date': '2023-02-17',
#   'publication_date': '2023-02-17',
#   'inventor': '徳志 劉',
#   'assignee': '広汽本田汽車有限公司',
#   'publication_number': 'JP7224473B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/c5/e9/fe/2cd67d23145205/0007224473000001.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/f3/8f/f0/57b87d98c122bf/JP7224473B2.pdf',
#   'page': 3},
#  {'position': 4,
#   'rank': 3,
#   'patent_id': 'patent/US10737578B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10737578B2%2Fen',
#   'title': 'Semi-active partial parallel battery architecture for an automotive vehicle …',
#   'priority_date': '2014-11-14',
#   'filing_date': '2018-05-14',
#   'grant_date': '2020-08-11',
#   'publication_date': '2020-08-11',
#   'inventor': 'Bryan L. Thieme',
#   'assignee': 'Cps Technology Holdings Llc',
#   'publication_number': 'US10737578B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/b9/d7/63/41b72cbd51c047/US10737578-20200811-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/77/db/c9/9f55de74fc20c3/US10737578.pdf',
#   'page': 3},
#  {'position': 5,
#   'rank': 4,
#   'patent_id': 'patent/JP6686187B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FJP6686187B2%2Fen',
#   'title': '… thin nozzle assembly and compact fluid circuit as an integrated automotive …',
#   'priority_date': '2014-04-11',
#   'filing_date': '2019-01-07',
#   'grant_date': '2020-04-22',
#   'publication_date': '2020-04-22',
#   'inventor': 'ラッセル・へスター',
#   'assignee': 'ディエルエイチ・ボウルズ・インコーポレイテッドｄｌｈＢＯＷＬＥＳ Ｉｎｃ．',
#   'publication_number': 'JP6686187B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/87/c7/42/9bba5ad74b6df8/0006686187-2.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/85/52/0d/bf41dd5a327753/JP6686187B2.pdf',
#   'page': 3},
#  {'position': 6,
#   'rank': 5,
#   'patent_id': 'patent/US10586217B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10586217B2%2Fen',
#   'title': 'Automotive ECU mobile phone interface',
#   'priority_date': '2006-06-13',
#   'filing_date': '2018-03-27',
#   'grant_date': '2020-03-10',
#   'publication_date': '2020-03-10',
#   'inventor': 'Hendalee Wilson',
#   'assignee': 'Cell Assist, LLC',
#   'publication_number': 'US10586217B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/0e/cc/6b/12d833476889ac/US10586217-20200310-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/72/90/4b/891a99e85331ca/US10586217.pdf',
#   'page': 3},
#  {'position': 7,
#   'rank': 6,
#   'patent_id': 'patent/US10984512B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10984512B2%2Fen',
#   'title': 'Method of providing automotive around view image using machine learning model',
#   'priority_date': '2018-07-09',
#   'filing_date': '2019-07-02',
#   'grant_date': '2021-04-20',
#   'publication_date': '2021-04-20',
#   'inventor': 'Hyun-Min JANG',
#   'assignee': 'Hyun-Min JANG',
#   'publication_number': 'US10984512B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/ce/99/55/ffb316468794c1/US10984512-20210420-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/f9/a2/41/c67e3db6fafb68/US10984512.pdf',
#   'page': 3},
#  {'position': 8,
#   'rank': 7,
#   'patent_id': 'patent/US10846166B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10846166B2%2Fen',
#   'title': 'Temporal anomaly detection on automotive networks',
#   'priority_date': '2014-12-30',
#   'filing_date': '2018-08-22',
#   'grant_date': '2020-11-24',
#   'publication_date': '2020-11-24',
#   'inventor': 'Anuja Sonalker',
#   'assignee': 'Batttelle Memorial Institute',
#   'publication_number': 'US10846166B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/0f/e5/cd/0da12b9d27702d/US10846166-20201124-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/34/8d/fc/ff7e2f2a4b9bbc/US10846166.pdf',
#   'page': 3},
#  {'position': 9,
#   'rank': 8,
#   'patent_id': 'patent/US11391428B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11391428B2%2Fen',
#   'title': 'Pixelated projection for automotive headlamp',
#   'priority_date': '2014-06-26',
#   'filing_date': '2021-04-07',
#   'grant_date': '2022-07-19',
#   'publication_date': '2022-07-19',
#   'inventor': 'Vikrant R. Bhakta',
#   'assignee': 'Texas Instruments Incorporated',
#   'publication_number': 'US11391428B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/82/4e/a5/5d4873f8b55657/US11391428-20220719-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/90/bf/07/a5f3c755c53837/US11391428.pdf',
#   'page': 3},
#  {'position': 10,
#   'rank': 9,
#   'patent_id': 'patent/CN109117560B/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FCN109117560B%2Fen',
#   'title': '… dimensional process design method and platform for machining parts of automotive …',
#   'priority_date': '2018-08-17',
#   'filing_date': '2018-08-17',
#   'grant_date': '2020-03-31',
#   'publication_date': '2020-03-31',
#   'inventor': '徐劲力',
#   'assignee': '武汉理工大学',
#   'publication_number': 'CN109117560B',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/c0/46/b2/7e644d4ea54766/HDA0001768809800000011.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/f0/79/c4/273aafd2154e41/CN109117560B.pdf',
#   'page': 3},
#  {'position': 1,
#   'rank': 0,
#   'patent_id': 'patent/US11853863B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11853863B2%2Fen',
#   'title': 'Predictive maintenance of automotive tires',
#   'priority_date': '2019-08-12',
#   'filing_date': '2019-08-12',
#   'grant_date': '2023-12-26',
#   'publication_date': '2023-12-26',
#   'inventor': 'Robert Richard Noel Bielby',
#   'assignee': 'Micron Technology, Inc.',
#   'publication_number': 'US11853863B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/16/bc/c5/b6b3c5fe9fcb5c/US11853863-20231226-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/65/0e/bd/8507de87ddd7a5/US11853863.pdf',
#   'page': 4},
#  {'position': 2,
#   'rank': 1,
#   'patent_id': 'patent/US10960838B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10960838B2%2Fen',
#   'title': 'Multi-sensor data fusion for automotive systems',
#   'priority_date': '2019-01-30',
#   'filing_date': '2020-01-30',
#   'grant_date': '2021-03-30',
#   'publication_date': '2021-03-30',
#   'inventor': 'Rana June Sobhany',
#   'assignee': 'Cobalt Industries Inc.',
#   'publication_number': 'US10960838B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/75/49/c2/711c22f3383d4e/US10960838-20210330-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/84/cd/7b/5347c82ab08e02/US10960838.pdf',
#   'page': 4},
#  {'position': 3,
#   'rank': 2,
#   'patent_id': 'patent/US10947677B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10947677B2%2Fen',
#   'title': 'Automotive milling machine, as well as method for unloading milled material',
#   'priority_date': '2012-08-23',
#   'filing_date': '2019-08-21',
#   'grant_date': '2021-03-16',
#   'publication_date': '2021-03-16',
#   'inventor': 'Christian Berning',
#   'assignee': 'Wirtgen Gmbh',
#   'publication_number': 'US10947677B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/35/6f/06/c6629a48d5d54b/US10947677-20210316-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/01/76/66/574464827337d4/US10947677.pdf',
#   'page': 4},
#  {'position': 4,
#   'rank': 3,
#   'patent_id': 'patent/KR102032475B1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FKR102032475B1%2Fen',
#   'title': 'Providing a communications channel between instances of automated assistants',
#   'priority_date': '2018-05-23',
#   'filing_date': '2019-05-15',
#   'grant_date': '2019-10-15',
#   'publication_date': '2019-10-15',
#   'inventor': '알렉산드르 말트세브',
#   'assignee': '구글 엘엘씨',
#   'publication_number': 'KR102032475B1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/4a/98/1e/478db35e842239/112019060494108-pat00001.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/35/33/9d/b33e1d49089eea/KR102032475B1.pdf',
#   'page': 4},
#  {'position': 5,
#   'rank': 4,
#   'patent_id': 'patent/US11269049B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11269049B2%2Fen',
#   'title': 'Distributed aperture automotive radar system',
#   'priority_date': '2019-03-18',
#   'filing_date': '2019-03-18',
#   'grant_date': '2022-03-08',
#   'publication_date': '2022-03-08',
#   'inventor': 'Ryan H. Wu',
#   'assignee': 'Nxp Usa, Inc.',
#   'publication_number': 'US11269049B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/a4/47/ec/013c528b6a8d18/US11269049-20220308-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/af/71/d6/940c81ce17508e/US11269049.pdf',
#   'page': 4},
#  {'position': 6,
#   'rank': 5,
#   'patent_id': 'patent/USD906888S1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUSD906888S1%2Fen',
#   'title': 'Automotive vehicle exterior body',
#   'priority_date': '2019-02-01',
#   'filing_date': '2019-02-01',
#   'grant_date': '2021-01-05',
#   'publication_date': '2021-01-05',
#   'inventor': 'Carlos Eduardo Satulovsky',
#   'assignee': 'ElATiON HYPERCARS, INC.',
#   'publication_number': 'USD906888S1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/65/75/34/2747d0c771cf8c/USD0906888-20210105-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/0e/0c/9a/039b9e24c47ac0/USD906888.pdf',
#   'page': 4},
#  {'position': 7,
#   'rank': 6,
#   'patent_id': 'patent/US20210222474A1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS20210222474A1%2Fen',
#   'title': 'Automotive door power assist',
#   'priority_date': '2015-07-29',
#   'filing_date': '2021-04-02',
#   'grant_date': None,
#   'publication_date': '2021-07-22',
#   'inventor': 'Larry Dean Elie',
#   'assignee': 'Ford Global Technologies, Llc',
#   'publication_number': 'US20210222474A1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/46/9b/d3/1d3da8ccffc748/US20210222474A1-20210722-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/05/56/5f/305dee66e06bcf/US20210222474A1.pdf',
#   'page': 4},
#  {'position': 8,
#   'rank': 7,
#   'patent_id': 'patent/US20230368577A1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS20230368577A1%2Fen',
#   'title': 'Automotive and industrial motion sensory device',
#   'priority_date': '2014-08-15',
#   'filing_date': '2023-07-24',
#   'grant_date': None,
#   'publication_date': '2023-11-16',
#   'inventor': 'David S. HOLZ',
#   'assignee': 'Ultrahaptics IP Two Limited',
#   'publication_number': 'US20230368577A1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/b1/4a/19/ed3e26b278e4a8/US20230368577A1-20231116-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/a3/11/d9/a8893077c49076/US20230368577A1.pdf',
#   'page': 4},
#  {'position': 9,
#   'rank': 8,
#   'patent_id': 'patent/JP6609005B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FJP6609005B2%2Fen',
#   'title': 'Automotive and automotive programs',
#   'priority_date': '2014-04-01',
#   'filing_date': '2018-07-09',
#   'grant_date': '2019-11-20',
#   'publication_date': '2019-11-20',
#   'inventor': '將洋 鈴木',
#   'assignee': 'みこらった株式会社',
#   'publication_number': 'JP6609005B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/db/93/d4/94d3f72ee7fb5d/0006609005-2.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/b9/76/fc/1d7ba34a3ad326/JP6609005B2.pdf',
#   'page': 4},
#  {'position': 10,
#   'rank': 9,
#   'patent_id': 'patent/US11232110B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11232110B2%2Fen',
#   'title': 'Natural language keyword tag extraction',
#   'priority_date': '2019-08-23',
#   'filing_date': '2019-08-23',
#   'grant_date': '2022-01-25',
#   'publication_date': '2022-01-25',
#   'inventor': 'Micah Price',
#   'assignee': 'Capital One Services, Llc',
#   'publication_number': 'US11232110B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/47/38/f1/574ee2a9d44a6f/US11232110-20220125-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/7e/1b/60/4ee52ce890b2e6/US11232110.pdf',
#   'page': 4},
#  {'position': 1,
#   'rank': 0,
#   'patent_id': 'patent/US11572024B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11572024B2%2Fen',
#   'title': 'Automotive laminate with superior camera window',
#   'priority_date': '2017-03-31',
#   'filing_date': '2021-03-20',
#   'grant_date': '2023-02-07',
#   'publication_date': '2023-02-07',
#   'inventor': 'Mario Arturo Mannheim Astete',
#   'assignee': 'Agp America S.A.',
#   'publication_number': 'US11572024B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/9f/04/ec/672827b24f895e/US11572024-20230207-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/9f/c4/68/d8b52f87ad25cf/US11572024.pdf',
#   'page': 5},
#  {'position': 2,
#   'rank': 1,
#   'patent_id': 'patent/US20210253471A1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS20210253471A1%2Fen',
#   'title': 'Automotive glass compositions, articles and hybrid laminates',
#   'priority_date': '2017-06-22',
#   'filing_date': '2021-05-06',
#   'grant_date': None,
#   'publication_date': '2021-08-19',
#   'inventor': 'Timothy Michael Gross',
#   'assignee': 'Corning Incorporated',
#   'publication_number': 'US20210253471A1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/2f/cb/ae/53180515b0cc74/US20210253471A1-20210819-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/8a/1d/25/c591ba5eaedb7f/US20210253471A1.pdf',
#   'page': 5},
#  {'position': 3,
#   'rank': 2,
#   'patent_id': 'patent/US11821981B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11821981B2%2Fen',
#   'title': 'Software defined automotive radar',
#   'priority_date': '2016-04-07',
#   'filing_date': '2023-03-28',
#   'grant_date': '2023-11-21',
#   'publication_date': '2023-11-21',
#   'inventor': 'Curtis Davis',
#   'assignee': 'Uhnder, Inc.',
#   'publication_number': 'US11821981B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/7c/28/d8/6c7b9cd96cc1b5/US11821981-20231121-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/aa/d8/00/e75bcbc3c95275/US11821981.pdf',
#   'page': 5},
#  {'position': 4,
#   'rank': 3,
#   'patent_id': 'patent/US11546448B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11546448B2%2Fen',
#   'title': 'System and method for data compression based on data position in frames …',
#   'priority_date': '2019-01-20',
#   'filing_date': '2022-03-19',
#   'grant_date': '2023-01-03',
#   'publication_date': '2023-01-03',
#   'inventor': 'Avraham Entelis',
#   'assignee': 'Arilou Information Security Technologies Ltd.',
#   'publication_number': 'US11546448B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/fe/30/22/af1f5b4d126867/US11546448-20230103-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/b9/d4/4b/eb08c89e82f29f/US11546448.pdf',
#   'page': 5},
#  {'position': 5,
#   'rank': 4,
#   'patent_id': 'patent/US11129312B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11129312B2%2Fen',
#   'title': 'Electronic module for use in an automotive vehicle',
#   'priority_date': '2017-11-20',
#   'filing_date': '2018-11-14',
#   'grant_date': '2021-09-21',
#   'publication_date': '2021-09-21',
#   'inventor': 'Darin Grinsteinner',
#   'assignee': 'Ticona Llc',
#   'publication_number': 'US11129312B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/b5/c6/5a/55910752480477/US11129312-20210921-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/39/b0/69/10dbc3cf07a4b1/US11129312.pdf',
#   'page': 5},
#  {'position': 6,
#   'rank': 5,
#   'patent_id': 'patent/US11906620B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11906620B2%2Fen',
#   'title': 'Software defined automotive radar systems',
#   'priority_date': '2016-04-07',
#   'filing_date': '2021-08-06',
#   'grant_date': '2024-02-20',
#   'publication_date': '2024-02-20',
#   'inventor': 'Curtis Davis',
#   'assignee': 'Uhnder, Inc.',
#   'publication_number': 'US11906620B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/2a/2f/f8/aa6044e80d076f/US11906620-20240220-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/59/2d/a3/7579fb401746e3/US11906620.pdf',
#   'page': 5},
#  {'position': 7,
#   'rank': 6,
#   'patent_id': 'patent/US10640040B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10640040B2%2Fen',
#   'title': 'Vision system for vehicle',
#   'priority_date': '2011-11-28',
#   'filing_date': '2018-09-10',
#   'grant_date': '2020-05-05',
#   'publication_date': '2020-05-05',
#   'inventor': 'Joern Ihlenburg',
#   'assignee': 'Magna Electronics Inc.',
#   'publication_number': 'US10640040B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/8f/be/71/5e3cd6546cb6fd/US10640040-20200505-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/57/63/1c/bdbae5b461e8af/US10640040.pdf',
#   'page': 5},
#  {'position': 8,
#   'rank': 7,
#   'patent_id': 'patent/US20210350237A1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS20210350237A1%2Fen',
#   'title': 'System and Method for using Signal Waveform Analysis for Detecting a Change in …',
#   'priority_date': '2016-12-07',
#   'filing_date': '2021-06-28',
#   'grant_date': None,
#   'publication_date': '2021-11-11',
#   'inventor': 'Gil Litichever',
#   'assignee': 'Arilou Information Security Technologies Ltd.',
#   'publication_number': 'US20210350237A1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/52/e9/13/435795a757dd32/US20210350237A1-20211111-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/55/14/1d/8e733466ed72ce/US20210350237A1.pdf',
#   'page': 5},
#  {'position': 9,
#   'rank': 8,
#   'patent_id': 'patent/US11288731B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11288731B2%2Fen',
#   'title': 'Personalized car recommendations based on customer web traffic',
#   'priority_date': '2019-12-27',
#   'filing_date': '2020-08-28',
#   'grant_date': '2022-03-29',
#   'publication_date': '2022-03-29',
#   'inventor': 'Micah Price',
#   'assignee': 'Capital One Services, Llc',
#   'publication_number': 'US11288731B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/c9/5d/3a/d94deca80a2284/US11288731-20220329-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/9c/b2/62/b806cb2ae6191c/US11288731.pdf',
#   'page': 5},
#  {'position': 10,
#   'rank': 9,
#   'patent_id': 'patent/JP6859505B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FJP6859505B2%2Fen',
#   'title': 'Image-based vehicle damage determination methods, devices and electronic …',
#   'priority_date': '2017-04-11',
#   'filing_date': '2018-04-11',
#   'grant_date': '2021-04-14',
#   'publication_date': '2021-04-14',
#   'inventor': 'ハイタオ・ジャン',
#   'assignee': 'アドバンスド ニュー テクノロジーズ カンパニー リミテッド',
#   'publication_number': 'JP6859505B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/c0/78/78/0fa46466678ea0/0006859505-2.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/b7/29/0a/19225daf74eeb0/JP6859505B2.pdf',
#   'page': 5},
#  {'position': 1,
#   'rank': 0,
#   'patent_id': 'patent/USD964258S1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUSD964258S1%2Fen',
#   'title': 'Automotive interior receptacle',
#   'priority_date': '2022-05-18',
#   'filing_date': '2022-05-18',
#   'grant_date': '2022-09-20',
#   'publication_date': '2022-09-20',
#   'inventor': 'Xin Tian',
#   'assignee': 'Shenzhen Zhengtu Auto Accessories Co., Ltd.',
#   'publication_number': 'USD964258S1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/9f/5f/fd/171def75df8042/USD0964258-20220920-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/36/22/5e/3d93ae1e75d1af/USD964258.pdf',
#   'page': 6},
#  {'position': 2,
#   'rank': 1,
#   'patent_id': 'patent/USD964259S1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUSD964259S1%2Fen',
#   'title': 'Automotive interior receptacle',
#   'priority_date': '2022-05-18',
#   'filing_date': '2022-05-18',
#   'grant_date': '2022-09-20',
#   'publication_date': '2022-09-20',
#   'inventor': 'Xin Tian',
#   'assignee': 'Shenzhen Zhengtu Auto Accessories Co., Ltd.',
#   'publication_number': 'USD964259S1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/45/81/47/d73ebaadb4017a/USD0964259-20220920-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/a7/67/3f/7a69f7eaa6d499/USD964259.pdf',
#   'page': 6},
#  {'position': 3,
#   'rank': 2,
#   'patent_id': 'patent/US10439192B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10439192B2%2Fen',
#   'title': 'Architectures for batteries having two different chemistries',
#   'priority_date': '2013-07-31',
#   'filing_date': '2018-08-27',
#   'grant_date': '2019-10-08',
#   'publication_date': '2019-10-08',
#   'inventor': 'Perry M. Wyatt',
#   'assignee': 'Cps Technology Holdings Llc',
#   'publication_number': 'US10439192B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/48/b5/15/4288679f07ee8d/US10439192-20191008-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/3d/b7/24/202f5dec7c72db/US10439192.pdf',
#   'page': 6},
#  {'position': 4,
#   'rank': 3,
#   'patent_id': 'patent/KR102335499B1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FKR102335499B1%2Fen',
#   'title': 'Automotive MIMO Radar Sensors',
#   'priority_date': '2016-12-14',
#   'filing_date': '2017-10-19',
#   'grant_date': '2021-12-07',
#   'publication_date': '2021-12-07',
#   'inventor': '베네딕트 뢰슈',
#   'assignee': '로베르트 보쉬 게엠베하',
#   'publication_number': 'KR102335499B1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/e4/fa/55/a9a851c88592cf/112019070914410-pct00016.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/7d/05/1b/0ba0db027a9c41/KR102335499B1.pdf',
#   'page': 6},
#  {'position': 5,
#   'rank': 4,
#   'patent_id': 'patent/US10176326B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10176326B2%2Fen',
#   'title': 'Secure controller operation and malware prevention',
#   'priority_date': '2016-04-06',
#   'filing_date': '2018-06-19',
#   'grant_date': '2019-01-08',
#   'publication_date': '2019-01-08',
#   'inventor': 'Tal Efraim Ben David',
# ...
#   'filing_date': '2018-06-01',
#   'grant_date': '2019-02-12',
#   'publication_date': '2019-02-12',
#   'inventor': 'Yekutiel Josefsberg',
#   'assignee': 'Yekutiel Josefsberg',
#   'publication_number': 'US10205457B1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/3e/21/68/59a92387cf580d/US10205457-20190212-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/87/c9/ab/6af685835acb1e/US10205457.pdf',
#   'page': 28},
#  {'position': 10,
#   'rank': 9,
#   'patent_id': 'patent/US11670121B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11670121B2%2Fen',
#   'title': 'Systems and methods for monitoring and reporting road quality',
#   'priority_date': '2012-01-31',
#   'filing_date': '2021-03-09',
#   'grant_date': '2023-06-06',
#   'publication_date': '2023-06-06',
#   'inventor': 'Dean K. Jackson',
#   'assignee': 'Google Llc',
#   'publication_number': 'US11670121B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/03/57/8a/960c38552b7a24/US11670121-20230606-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/91/32/6a/5f8439a4c0c7aa/US11670121.pdf',
#   'page': 28},
#  {'position': 1,
#   'rank': 0,
#   'patent_id': 'patent/KR102635379B1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FKR102635379B1%2Fen',
#   'title': 'Method and apparatus for vehicle maneuver planning and messaging',
#   'priority_date': '2019-04-29',
#   'filing_date': '2020-04-14',
#   'grant_date': '2024-02-08',
#   'publication_date': '2024-02-08',
#   'inventor': '단 바실로프스키',
#   'assignee': '퀄컴 인코포레이티드',
#   'publication_number': 'KR102635379B1',
#   'language': 'en',
#   'thumbnail': None,
#   'pdf': 'https://patentimages.storage.googleapis.com/58/11/e5/fb25638b88f08d/KR102635379B1.pdf',
#   'page': 29},
#  {'position': 2,
#   'rank': 1,
#   'patent_id': 'patent/CN108973979B/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FCN108973979B%2Fen',
#   'title': 'Hybrid vehicle predictive power control system scheme',
#   'priority_date': '2018-07-18',
#   'filing_date': '2018-07-18',
#   'grant_date': '2021-09-28',
#   'publication_date': '2021-09-28',
#   'inventor': '格桑旺杰',
#   'assignee': '乾碳国际公司',
#   'publication_number': 'CN108973979B',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/31/ae/84/9b6724eb90ae32/HDA0001735299920000011.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/ff/0a/bb/dd5614cb7069a8/CN108973979B.pdf',
#   'page': 29},
#  {'position': 3,
#   'rank': 2,
#   'patent_id': 'patent/CN110823235B/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FCN110823235B%2Fen',
#   'title': 'Intelligent vehicle navigation system, method and control logic for deriving …',
#   'priority_date': '2018-08-07',
#   'filing_date': '2019-06-01',
#   'grant_date': '2024-01-02',
#   'publication_date': '2024-01-02',
#   'inventor': 'F·白',
#   'assignee': '通用汽车环球科技运作有限责任公司',
#   'publication_number': 'CN110823235B',
#   'language': 'en',
#   'thumbnail': None,
#   'pdf': 'https://patentimages.storage.googleapis.com/3c/a4/18/2f873f645c5000/CN110823235B.pdf',
#   'page': 29},
#  {'position': 4,
#   'rank': 3,
#   'patent_id': 'patent/US20210395528A1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS20210395528A1%2Fen',
#   'title': 'Separators, batteries, systems, and methods for idle start stop vehicles',
#   'priority_date': '2010-09-22',
#   'filing_date': '2021-08-31',
#   'grant_date': None,
#   'publication_date': '2021-12-23',
#   'inventor': 'J. Kevin Whear',
#   'assignee': 'Daramic, Llc',
#   'publication_number': 'US20210395528A1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/c2/1d/79/f2bc61e9839b26/US20210395528A1-20211223-D00001.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/06/86/6e/d20216c04eba85/US20210395528A1.pdf',
#   'page': 29},
#  {'position': 5,
#   'rank': 4,
#   'patent_id': 'patent/US11305517B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11305517B2%2Fen',
#   'title': 'Stiff interlayers for laminated glass structures',
#   'priority_date': '2012-05-31',
#   'filing_date': '2020-02-12',
#   'grant_date': '2022-04-19',
#   'publication_date': '2022-04-19',
#   'inventor': 'William Keith Fisher',
#   'assignee': 'Corning Incorporated',
#   'publication_number': 'US11305517B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/35/ae/93/336cc5982f13cc/US11305517-20220419-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/cf/76/68/d462686178415d/US11305517.pdf',
#   'page': 29},
#  {'position': 6,
#   'rank': 5,
#   'patent_id': 'patent/US11776279B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11776279B2%2Fen',
#   'title': 'Method and apparatus for providing unknown moving object detection',
#   'priority_date': '2017-12-19',
#   'filing_date': '2020-12-28',
#   'grant_date': '2023-10-03',
#   'publication_date': '2023-10-03',
#   'inventor': 'James Fowe',
#   'assignee': 'Here Global B.V.',
#   'publication_number': 'US11776279B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/ff/f6/b3/4365600be8c65d/US11776279-20231003-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/73/dc/2e/600f9a0783b379/US11776279.pdf',
#   'page': 29},
#  {'position': 7,
#   'rank': 6,
#   'patent_id': 'patent/JP7403293B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FJP7403293B2%2Fen',
#   'title': 'Gaze detection using one or more neural networks',
#   'priority_date': '2019-08-19',
#   'filing_date': '2019-11-29',
#   'grant_date': '2023-12-22',
#   'publication_date': '2023-12-22',
#   'inventor': 'フー フェン',
#   'assignee': 'エヌビディア コーポレーション',
#   'publication_number': 'JP7403293B2',
#   'language': 'en',
#   'thumbnail': None,
#   'pdf': 'https://patentimages.storage.googleapis.com/44/9a/2a/210b22434dc938/JP7403293B2.pdf',
#   'page': 29},
#  {'position': 8,
#   'rank': 7,
#   'patent_id': 'patent/US11594082B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11594082B2%2Fen',
#   'title': 'Vehicle fault detection system and method utilizing graphically converted …',
#   'priority_date': '2017-10-27',
#   'filing_date': '2022-01-18',
#   'grant_date': '2023-02-28',
#   'publication_date': '2023-02-28',
#   'inventor': 'John M. Boggio',
#   'assignee': 'The Boeing Company',
#   'publication_number': 'US11594082B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/4e/10/68/981241879380aa/US11594082-20230228-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/a6/de/df/f7bf6ec97abd38/US11594082B2.pdf',
#   'page': 29},
#  {'position': 9,
#   'rank': 8,
#   'patent_id': 'patent/EP3823384B1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FEP3823384B1%2Fen',
#   'title': 'Methods for transmitting and receiving uplink data in a wireless communication …',
#   'priority_date': '2018-08-09',
#   'filing_date': '2019-08-08',
#   'grant_date': '2023-11-15',
#   'publication_date': '2023-11-15',
#   'inventor': 'Seokmin SHIN',
#   'assignee': 'LG Electronics Inc.',
#   'publication_number': 'EP3823384B1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/c4/f9/b8/59af6398841f6a/imgf0001.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/3a/17/85/c9c48870506439/EP3823384B1.pdf',
#   'page': 29},
#  {'position': 10,
#   'rank': 9,
#   'patent_id': 'patent/US11774963B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11774963B2%2Fen',
#   'title': 'Remote operation of a vehicle using virtual representations of a vehicle state',
#   'priority_date': '2018-03-27',
#   'filing_date': '2021-07-19',
#   'grant_date': '2023-10-03',
#   'publication_date': '2023-10-03',
#   'inventor': 'Jen-Hsun Huang',
#   'assignee': 'Nvidia Corporation',
#   'publication_number': 'US11774963B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/21/79/30/6249420d7b0440/US11774963-20231003-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/21/50/8b/6adee7a15a636d/US11774963.pdf',
#   'page': 29},
#  {'position': 1,
#   'rank': 0,
#   'patent_id': 'patent/US10972975B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10972975B2%2Fen',
#   'title': 'Electronic device for transmitting communication signal related to pedestrian …',
#   'priority_date': '2017-08-10',
#   'filing_date': '2018-07-27',
#   'grant_date': '2021-04-06',
#   'publication_date': '2021-04-06',
#   'inventor': 'Ga-Jin SONG',
#   'assignee': 'Samsung Electronics Co., Ltd.',
#   'publication_number': 'US10972975B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/7a/11/1c/a8f7915fb2cbab/US10972975-20210406-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/49/8e/36/ce45f507e34a6c/US10972975.pdf',
#   'page': 30},
#  {'position': 2,
#   'rank': 1,
#   'patent_id': 'patent/US11860130B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11860130B2%2Fen',
#   'title': 'Systems, methods, and devices for health monitoring of an energy storage device',
#   'priority_date': '2013-08-15',
#   'filing_date': '2022-11-01',
#   'grant_date': '2024-01-02',
#   'publication_date': '2024-01-02',
#   'inventor': 'Bhanu SOOD',
#   'assignee': 'University Of Maryland, College Park',
#   'publication_number': 'US11860130B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/04/5e/5d/05144b34a1eea4/US11860130-20240102-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/5b/95/86/c19fe4efd9ea19/US11860130.pdf',
#   'page': 30},
#  {'position': 3,
#   'rank': 2,
#   'patent_id': 'patent/US10551838B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10551838B2%2Fen',
#   'title': 'Method and system for multiple sensor correlation diagnostic and sensor fusion/ …',
#   'priority_date': '2017-08-08',
#   'filing_date': '2017-08-08',
#   'grant_date': '2020-02-04',
#   'publication_date': '2020-02-04',
#   'inventor': 'Xiaodong Liu',
#   'assignee': 'Nio Usa, Inc.',
#   'publication_number': 'US10551838B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/c5/bb/0b/b119aac36e07bf/US10551838-20200204-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/28/c6/d6/3ac213117f1356/US10551838.pdf',
#   'page': 30},
#  {'position': 4,
#   'rank': 3,
#   'patent_id': 'patent/US10661716B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10661716B2%2Fen',
#   'title': 'Vehicular exterior electrically variable reflectance mirror reflective element …',
#   'priority_date': '2002-09-20',
#   'filing_date': '2019-07-29',
#   'grant_date': '2020-05-26',
#   'publication_date': '2020-05-26',
#   'inventor': 'Ian A. McCabe',
#   'assignee': 'Donnelly Corporation',
#   'publication_number': 'US10661716B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/c8/89/c9/74c32af51d0e53/US10661716-20200526-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/4e/c1/e6/cf5f9995d160fa/US10661716.pdf',
#   'page': 30},
#  {'position': 5,
#   'rank': 4,
#   'patent_id': 'patent/US20220036256A1/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS20220036256A1%2Fen',
#   'title': 'Vehicle access control services and platform',
#   'priority_date': '2009-10-30',
#   'filing_date': '2021-05-17',
#   'grant_date': None,
#   'publication_date': '2022-02-03',
#   'inventor': 'Sam Zaid',
#   'assignee': 'Getaround, Inc.',
#   'publication_number': 'US20220036256A1',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/c3/44/9a/02edfef41c2883/US20220036256A1-20220203-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/e0/28/f0/4204834a24ff70/US20220036256A1.pdf',
#   'page': 30},
#  {'position': 6,
#   'rank': 5,
#   'patent_id': 'patent/US11099267B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11099267B2%2Fen',
#   'title': 'Extended doppler PMCW code division MIMO radar',
#   'priority_date': '2018-12-18',
#   'filing_date': '2018-12-18',
#   'grant_date': '2021-08-24',
#   'publication_date': '2021-08-24',
#   'inventor': 'Ryan Haoyun Wu',
#   'assignee': 'Nxp Usa, Inc.',
#   'publication_number': 'US11099267B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/8a/e4/10/07dc10a8aaa354/US11099267-20210824-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/fe/8d/79/1f641e12f80980/US11099267.pdf',
#   'page': 30},
#  {'position': 7,
#   'rank': 6,
#   'patent_id': 'patent/US11808607B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11808607B2%2Fen',
#   'title': 'Ranging apparatus and moving object capable of high-accuracy ranging',
#   'priority_date': '2016-03-14',
#   'filing_date': '2020-05-18',
#   'grant_date': '2023-11-07',
#   'publication_date': '2023-11-07',
#   'inventor': 'Akinari Takagi',
#   'assignee': 'Canon Kabushiki Kaisha',
#   'publication_number': 'US11808607B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/49/9b/a2/da5a2eb5fb406c/US11808607-20231107-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/59/78/56/0951c10e7029f5/US11808607.pdf',
#   'page': 30},
#  {'position': 8,
#   'rank': 7,
#   'patent_id': 'patent/US11454699B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS11454699B2%2Fen',
#   'title': 'FMCW radar system on a chip measuring phase noise',
#   'priority_date': '2014-12-29',
#   'filing_date': '2019-02-26',
#   'grant_date': '2022-09-27',
#   'publication_date': '2022-09-27',
#   'inventor': 'Brian Paul Ginsburg',
#   'assignee': 'Texas Instruments Incorporated',
#   'publication_number': 'US11454699B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/87/56/1c/916141baaa35b1/US11454699-20220927-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/26/cf/de/bd16d6f9083f2f/US11454699.pdf',
#   'page': 30},
#  {'position': 9,
#   'rank': 8,
#   'patent_id': 'patent/US10903892B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS10903892B2%2Fen',
#   'title': 'Method for performing uplink transmission in wireless communication system and …',
#   'priority_date': '2018-08-22',
#   'filing_date': '2020-02-07',
#   'grant_date': '2021-01-26',
#   'publication_date': '2021-01-26',
#   'inventor': 'Jiwon Kang',
#   'assignee': 'Lg Electronics Inc.',
#   'publication_number': 'US10903892B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/5f/d1/95/df6f0653fd89ca/US10903892-20210126-D00000.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/84/a2/46/7bb0569e429dc8/US10903892.pdf',
#   'page': 30},
#  {'position': 10,
#   'rank': 9,
#   'patent_id': 'patent/JP7277461B2/en',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FJP7277461B2%2Fen',
#   'title': 'Rotating Compact Optical Ranging System',
#   'priority_date': '2017-12-07',
#   'filing_date': '2018-12-06',
#   'grant_date': '2023-05-19',
#   'publication_date': '2023-05-19',
#   'inventor': 'アンガス パカラ',
#   'assignee': 'アウスター インコーポレイテッド',
#   'publication_number': 'JP7277461B2',
#   'language': 'en',
#   'thumbnail': 'https://patentimages.storage.googleapis.com/ca/8b/7c/3bcaf46bebebdd/0007277461000001.png',
#   'pdf': 'https://patentimages.storage.googleapis.com/35/1f/ee/df30531756adb7/JP7277461B2.pdf',
#   'page': 30}]

# %%
csv_file = "extracted_data.csv" # Assign .csv file name to a variable
csv_columns = [                 # Define list of columns for your .csv file
            "position",
            "rank",
            "patent_id",
            "serpapi_link",
            "title",
            "priority_date",
            "filing_date",
            "grant_date",
            "publication_date",
            "inventor",
            "assignee",
            "publication_number",
            "language",
            "thumbnail",
            "pdf",
            "page"
    ]   


# Save all extracted data to a CSV file
df = pd.DataFrame(data=all_extracted_data)
df = df.drop_duplicates(subset='patent_id', keep="last")
df.to_csv(
    csv_file, 
    columns=csv_columns, 
    encoding="utf-8", 
    index=False
    )

# %%
df.head()
# Out:
#     position  rank                  patent_id  \
# 10         1     0     patent/US10427604B2/en
# 11         2     1  patent/US20210234767A1/en
# 12         3     2     patent/US10979875B2/en
# 13         4     3     patent/US10320836B2/en
# 14         5     4     patent/US11790420B2/en
#
#                                          serpapi_link  \
# 10  https://serpapi.com/search.json?engine=google_...
# 11  https://serpapi.com/search.json?engine=google_...
# 12  https://serpapi.com/search.json?engine=google_...
# 13  https://serpapi.com/search.json?engine=google_...
# 14  https://serpapi.com/search.json?engine=google_...
#
#                                                 title priority_date  \
# 10                        Vision system for a vehicle    2000-03-02
# 11                                 Vehicle middleware    2011-11-16
# 12  System and method for wireless interface selec...    2011-01-14
# 13  Automotive ECU controller and data network hav...    2017-01-03
# 14  Visual discovery tool for automotive manufactu...    2016-10-18
#
#    filing_date  grant_date publication_date               inventor  \
# 10  2018-08-27  2019-10-01       2019-10-01      Kenneth Schofield
# 11  2021-04-16        None       2021-07-29   Christopher P. Ricci
# 12  2018-09-11  2021-04-13       2021-04-13        Lillian Lei Dai
# 13  2018-07-16  2019-06-11       2019-06-11   Tal Efraim Ben David
# 14  2021-01-04  2023-10-17       2023-10-17  Jeffrey Stuart Cotton
#
#                     assignee publication_number language  \
# 10    Magna Electronics Inc.       US10427604B2       en
# 11  Autoconnect Holdings Llc    US20210234767A1       en
# 12    Cisco Technology, Inc.       US10979875B2       en
# 13     Karamba Security Ltd.       US10320836B2       en
# 14            Autoalert, Llc       US11790420B2       en
#
#                                             thumbnail  \
# 10  https://patentimages.storage.googleapis.com/24...
# 11  https://patentimages.storage.googleapis.com/aa...
# 12  https://patentimages.storage.googleapis.com/46...
# 13  https://patentimages.storage.googleapis.com/50...
# 14  https://patentimages.storage.googleapis.com/38...
#
#                                                   pdf  page
# 10  https://patentimages.storage.googleapis.com/57...   1.0
# 11  https://patentimages.storage.googleapis.com/42...   1.0
# 12  https://patentimages.storage.googleapis.com/31...   1.0
# 13  https://patentimages.storage.googleapis.com/40...   1.0
# 14  https://patentimages.storage.googleapis.com/f7...   1.0

# %%
df.shape
# Out:
# (300, 16)
